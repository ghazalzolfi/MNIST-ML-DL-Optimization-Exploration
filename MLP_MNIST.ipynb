# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Ghazal Zolfi Moselo
# Student-ID: 401104146

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, np.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(
    x, y_new, test_size=10000, random_state=SEED, shuffle=True
)

# -------------------------------- TODO -------------------------------------

# %%
print("Training data:", x_train.shape)
print("Test data:", x_test.shape)
print("Training labels:", y_train.shape)
print("Test labels:", y_test.shape)
# Out:
# Training data: (60000, 784)
# Test data: (10000, 784)
# Training labels: (60000, 10)
# Test labels: (10000, 10)

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # -------------------------------- TODO -------------------------------------

        # Do the same for other activation functions
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu

        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, 0)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return 1 - np.tanh(x) ** 2
        else:
            return np.tanh(x)
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        sig = 1 / (1 + np.exp(-x))
        if derivative:
            return sig * (1 - sig)
        else:
            return sig
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        exps = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exps / np.sum(exps, axis=1, keepdims=True)
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1,alpha)
        else:
            return np.where(x > 0, x,alpha * x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers + 1):
          W = self.params[f"W{i}"]
          b = self.params[f"b{i}"]
          A_prev = self.cache[f"A{i-1}"]
          z = np.dot(W, A_prev) + b
          self.cache[f"Z{i}"] = z
          if i == self.num_layers:
            self.cache[f"A{i}"] = self.softmax(z.T).T
          else:
            self.cache[f"A{i}"] = self.activation(z)
        # -------------------------------- TODO -------------------------------------

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}

        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        dA = output - y.T
        for i in reversed(range(1, self.num_layers + 1)):

            grads[f"W{i}"] = np.dot(dA, self.cache[f"A{i-1}"].T) / current_batch_size
            grads[f"b{i}"] = np.sum(dA, axis=1, keepdims=True) / current_batch_size

            if i > 1:
                W = self.params[f"W{i}"]
                dA = np.dot(W.T,dA) * self.activation(self.cache[f"Z{i-1}"], derivative=True)
        # -------------------------------- TODO -------------------------------------

        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels

        l = -np.sum(y * np.log(output.T + 1e-8)) / y.shape[0]

        # -------------------------------- TODO -------------------------------------
        return l

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momemtum_opt[f"dW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momemtum_opt[f"db{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return momemtum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"fW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"sW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"fb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"sb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                self.momemtum_opt[f"d{key}"] = beta * self.momemtum_opt[f"d{key}"] + (1 - beta) * self.grads[key]
                self.params[key] -= l_rate * self.momemtum_opt[f"d{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                for key in self.params:
                  self.adam_opt[f"f{key}"] = beta1 * self.adam_opt[f"f{key}"] + (1 - beta1) * self.grads[key]
                  self.adam_opt[f"s{key}"] = beta2 * self.adam_opt[f"s{key}"] + (1 - beta2) * (self.grads[key]**2)
                  m_corrected = self.adam_opt[f"f{key}"] / (1 - beta1**t)
                  v_corrected = self.adam_opt[f"s{key}"] / (1 - beta2**t)
                  self.params[key] -= l_rate * m_corrected / (np.sqrt(v_corrected) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        predictions = np.argmax(output, axis=0)
        labels = np.argmax(y.T, axis=0)
        return np.mean(predictions == labels)
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...
optimizers = ['sgd', 'momentum', 'adam']
activations = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
epochs = 20
layers = [128, 64, 10]
learning_rates = [0.01, 0.001]

results = []

def training_evaluating(optimizer, activation, learning_rate):
    model = MLP(sizes=[784] + layers, activation=activation)
    model.train(x_train, y_train, x_test, y_test, epochs=epochs, optimizer=optimizer, l_rate=learning_rate)
    test_output = model.feed_forward(x_test)
    test_accuracy = model.accuracy(y_test, test_output)
    return test_accuracy

for optimizer in optimizers:
    for activation in activations:
        for learning_rate in learning_rates:
            print(f"Optimizer:{optimizer}, Activation:{activation}, LearningRate:{learning_rate}")
            accuracy = training_evaluating(optimizer, activation, learning_rate)
            results.append({
                "Optimizer": optimizer,
                "Activation": activation,
                "Learning Rate": learning_rate,
                "Accuracy": accuracy
            })
# Out:
# Optimizer:sgd, Activation:relu, LearningRate:0.01
# Epoch 1: 3.14s, train acc=0.87, train loss=0.49, validation acc=0.86, validation loss=0.52
# Epoch 2: 8.86s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 3: 11.86s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 4: 14.89s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 5: 17.86s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.30
# Epoch 6: 23.56s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 7: 26.52s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 8: 29.57s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.25
# Epoch 9: 32.56s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.23
# Epoch 10: 38.43s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.22
# Epoch 11: 41.42s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.21
# Epoch 12: 44.36s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.20
# Epoch 13: 47.35s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 14: 53.27s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.19
# Epoch 15: 56.24s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.18
# Epoch 16: 59.34s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 17: 62.35s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 18: 67.83s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 72.43s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 20: 75.44s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.16
# Optimizer:sgd, Activation:relu, LearningRate:0.001
# Epoch 1: 4.21s, train acc=0.41, train loss=2.09, validation acc=0.40, validation loss=2.09
# Epoch 2: 8.65s, train acc=0.57, train loss=1.76, validation acc=0.56, validation loss=1.77
# Epoch 3: 11.66s, train acc=0.72, train loss=1.37, validation acc=0.71, validation loss=1.38
# Epoch 4: 14.70s, train acc=0.78, train loss=1.04, validation acc=0.78, validation loss=1.05
# Epoch 5: 18.44s, train acc=0.82, train loss=0.82, validation acc=0.81, validation loss=0.85
# Epoch 6: 23.04s, train acc=0.84, train loss=0.69, validation acc=0.83, validation loss=0.72
# Epoch 7: 25.99s, train acc=0.85, train loss=0.61, validation acc=0.84, validation loss=0.63
# Epoch 8: 28.90s, train acc=0.86, train loss=0.55, validation acc=0.85, validation loss=0.58
# Epoch 9: 32.47s, train acc=0.87, train loss=0.50, validation acc=0.86, validation loss=0.54
# Epoch 10: 37.39s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.51
# Epoch 11: 40.31s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 12: 43.24s, train acc=0.89, train loss=0.43, validation acc=0.87, validation loss=0.46
# Epoch 13: 46.38s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 14: 51.87s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 15: 54.88s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.42
# Epoch 16: 57.85s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 17: 61.02s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 18: 66.65s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 19: 69.58s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 72.56s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.39
#
# Test acc=0.89, Test loss=0.39
# Optimizer:sgd, Activation:sigmoid, LearningRate:0.01
# Epoch 1: 4.28s, train acc=0.20, train loss=2.25, validation acc=0.20, validation loss=2.25
# Epoch 2: 9.82s, train acc=0.53, train loss=2.17, validation acc=0.53, validation loss=2.17
# Epoch 3: 13.55s, train acc=0.61, train loss=1.99, validation acc=0.60, validation loss=1.99
# Epoch 4: 17.19s, train acc=0.63, train loss=1.66, validation acc=0.62, validation loss=1.66
# Epoch 5: 23.42s, train acc=0.69, train loss=1.31, validation acc=0.68, validation loss=1.32
# Epoch 6: 26.99s, train acc=0.73, train loss=1.07, validation acc=0.72, validation loss=1.08
# Epoch 7: 30.59s, train acc=0.77, train loss=0.91, validation acc=0.76, validation loss=0.92
# Epoch 8: 35.84s, train acc=0.79, train loss=0.80, validation acc=0.79, validation loss=0.81
# Epoch 9: 40.39s, train acc=0.82, train loss=0.71, validation acc=0.82, validation loss=0.73
# Epoch 10: 44.00s, train acc=0.83, train loss=0.64, validation acc=0.83, validation loss=0.66
# Epoch 11: 47.71s, train acc=0.84, train loss=0.59, validation acc=0.84, validation loss=0.61
# Epoch 12: 53.79s, train acc=0.85, train loss=0.55, validation acc=0.85, validation loss=0.57
# Epoch 13: 57.42s, train acc=0.86, train loss=0.52, validation acc=0.86, validation loss=0.54
# Epoch 14: 60.99s, train acc=0.87, train loss=0.49, validation acc=0.86, validation loss=0.52
# Epoch 15: 67.22s, train acc=0.87, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 16: 70.92s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 17: 74.57s, train acc=0.88, train loss=0.43, validation acc=0.87, validation loss=0.46
# Epoch 18: 79.24s, train acc=0.88, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 19: 84.38s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 20: 88.07s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
#
# Test acc=0.88, Test loss=0.43
# Optimizer:sgd, Activation:sigmoid, LearningRate:0.001
# Epoch 1: 3.83s, train acc=0.11, train loss=2.30, validation acc=0.10, validation loss=2.30
# Epoch 2: 10.20s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 3: 13.84s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 4: 17.46s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 5: 23.64s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 6: 27.26s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 7: 30.91s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 8: 35.47s, train acc=0.17, train loss=2.27, validation acc=0.18, validation loss=2.27
# Epoch 9: 40.81s, train acc=0.16, train loss=2.27, validation acc=0.17, validation loss=2.27
# Epoch 10: 44.47s, train acc=0.19, train loss=2.26, validation acc=0.19, validation loss=2.26
# Epoch 11: 48.05s, train acc=0.22, train loss=2.26, validation acc=0.22, validation loss=2.26
# Epoch 12: 54.34s, train acc=0.22, train loss=2.25, validation acc=0.23, validation loss=2.25
# Epoch 13: 57.94s, train acc=0.25, train loss=2.24, validation acc=0.25, validation loss=2.25
# Epoch 14: 63.35s, train acc=0.30, train loss=2.24, validation acc=0.30, validation loss=2.24
# Epoch 15: 69.42s, train acc=0.32, train loss=2.23, validation acc=0.32, validation loss=2.23
# Epoch 16: 73.14s, train acc=0.33, train loss=2.22, validation acc=0.33, validation loss=2.23
# Epoch 17: 76.77s, train acc=0.35, train loss=2.22, validation acc=0.35, validation loss=2.22
# Epoch 18: 83.00s, train acc=0.38, train loss=2.21, validation acc=0.37, validation loss=2.21
# Epoch 19: 86.63s, train acc=0.39, train loss=2.20, validation acc=0.39, validation loss=2.20
# Epoch 20: 90.27s, train acc=0.40, train loss=2.19, validation acc=0.40, validation loss=2.19
#
# Test acc=0.40, Test loss=2.19
# Optimizer:sgd, Activation:tanh, LearningRate:0.01
# Epoch 1: 8.18s, train acc=0.88, train loss=0.49, validation acc=0.87, validation loss=0.53
# Epoch 2: 13.73s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 3: 20.91s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 4: 26.65s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.33
# Epoch 5: 32.45s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 6: 39.71s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.30
# Epoch 7: 45.22s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.29
# Epoch 8: 53.34s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 9: 58.89s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 10: 67.03s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 11: 72.63s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 12: 80.30s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 13: 85.80s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 14: 92.39s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 15: 98.79s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 16: 104.56s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 17: 114.74s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 18: 120.67s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 19: 127.87s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 20: 133.39s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
#
# Test acc=0.94, Test loss=0.20
# Optimizer:sgd, Activation:tanh, LearningRate:0.001
# Epoch 1: 7.91s, train acc=0.65, train loss=1.74, validation acc=0.65, validation loss=1.74
# Epoch 2: 13.37s, train acc=0.75, train loss=1.32, validation acc=0.74, validation loss=1.34
# Epoch 3: 21.46s, train acc=0.79, train loss=1.05, validation acc=0.78, validation loss=1.07
# Epoch 4: 27.80s, train acc=0.82, train loss=0.88, validation acc=0.81, validation loss=0.90
# Epoch 5: 37.55s, train acc=0.84, train loss=0.77, validation acc=0.83, validation loss=0.79
# Epoch 6: 43.13s, train acc=0.85, train loss=0.68, validation acc=0.84, validation loss=0.71
# Epoch 7: 50.92s, train acc=0.86, train loss=0.62, validation acc=0.85, validation loss=0.65
# Epoch 8: 56.53s, train acc=0.87, train loss=0.58, validation acc=0.86, validation loss=0.61
# Epoch 9: 62.82s, train acc=0.87, train loss=0.54, validation acc=0.86, validation loss=0.57
# Epoch 10: 69.37s, train acc=0.88, train loss=0.51, validation acc=0.87, validation loss=0.54
# Epoch 11: 74.77s, train acc=0.88, train loss=0.49, validation acc=0.87, validation loss=0.52
# Epoch 12: 82.65s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 13: 88.12s, train acc=0.89, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 14: 96.05s, train acc=0.89, train loss=0.44, validation acc=0.88, validation loss=0.47
# Epoch 15: 101.52s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 16: 109.25s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 17: 114.72s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 18: 121.47s, train acc=0.90, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 19: 127.37s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 20: 133.00s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
#
# Test acc=0.89, Test loss=0.41
# Optimizer:sgd, Activation:leaky_relu, LearningRate:0.01
# Epoch 1: 4.98s, train acc=0.87, train loss=0.48, validation acc=0.86, validation loss=0.51
# Epoch 2: 8.04s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.38
# Epoch 3: 11.01s, train acc=0.91, train loss=0.30, validation acc=0.90, validation loss=0.35
# Epoch 4: 14.43s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 5: 19.41s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.29
# Epoch 6: 22.46s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 7: 25.53s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 8: 29.11s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 9: 34.05s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 10: 37.14s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 11: 40.23s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 12: 44.12s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 13: 48.90s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 14: 51.98s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 15: 55.09s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 16: 59.24s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 17: 63.50s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 18: 66.54s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 69.63s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.17
# Epoch 20: 73.93s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.16
# Optimizer:sgd, Activation:leaky_relu, LearningRate:0.001
# Epoch 1: 4.19s, train acc=0.51, train loss=2.06, validation acc=0.50, validation loss=2.06
# Epoch 2: 7.25s, train acc=0.65, train loss=1.68, validation acc=0.63, validation loss=1.69
# Epoch 3: 10.30s, train acc=0.72, train loss=1.27, validation acc=0.71, validation loss=1.29
# Epoch 4: 14.48s, train acc=0.77, train loss=0.99, validation acc=0.76, validation loss=1.00
# Epoch 5: 18.61s, train acc=0.80, train loss=0.81, validation acc=0.79, validation loss=0.83
# Epoch 6: 21.62s, train acc=0.83, train loss=0.70, validation acc=0.82, validation loss=0.73
# Epoch 7: 24.70s, train acc=0.84, train loss=0.62, validation acc=0.83, validation loss=0.65
# Epoch 8: 28.94s, train acc=0.85, train loss=0.57, validation acc=0.84, validation loss=0.60
# Epoch 9: 33.00s, train acc=0.86, train loss=0.52, validation acc=0.85, validation loss=0.56
# Epoch 10: 35.99s, train acc=0.87, train loss=0.49, validation acc=0.86, validation loss=0.53
# Epoch 11: 38.99s, train acc=0.87, train loss=0.46, validation acc=0.86, validation loss=0.50
# Epoch 12: 43.11s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.48
# Epoch 13: 47.37s, train acc=0.88, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 14: 50.35s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 15: 53.36s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 16: 57.38s, train acc=0.89, train loss=0.38, validation acc=0.88, validation loss=0.42
# Epoch 17: 61.80s, train acc=0.90, train loss=0.38, validation acc=0.88, validation loss=0.42
# Epoch 18: 64.78s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 19: 67.78s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 20: 71.41s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
#
# Test acc=0.89, Test loss=0.39
# Optimizer:sgd, Activation:selu, LearningRate:0.01
# Epoch 1: 5.34s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 2: 9.21s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.36
# Epoch 3: 13.23s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.33
# Epoch 4: 19.34s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 5: 23.22s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.30
# Epoch 6: 27.03s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 7: 33.23s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 8: 37.06s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 9: 40.91s, train acc=0.94, train loss=0.21, validation acc=0.92, validation loss=0.27
# Epoch 10: 48.31s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 11: 53.06s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 12: 57.06s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.23
# Epoch 13: 62.92s, train acc=0.95, train loss=0.17, validation acc=0.93, validation loss=0.23
# Epoch 14: 66.75s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.22
# Epoch 15: 70.59s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 16: 77.15s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.21
# Epoch 17: 80.97s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 18: 84.81s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.19
# Epoch 19: 91.12s, train acc=0.96, train loss=0.13, validation acc=0.94, validation loss=0.19
# Epoch 20: 94.95s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
#
# Test acc=0.95, Test loss=0.18
# Optimizer:sgd, Activation:selu, LearningRate:0.001
# Epoch 1: 3.78s, train acc=0.76, train loss=1.06, validation acc=0.75, validation loss=1.09
# Epoch 2: 10.06s, train acc=0.83, train loss=0.74, validation acc=0.82, validation loss=0.77
# Epoch 3: 13.92s, train acc=0.85, train loss=0.61, validation acc=0.84, validation loss=0.64
# Epoch 4: 17.76s, train acc=0.87, train loss=0.53, validation acc=0.86, validation loss=0.56
# Epoch 5: 23.98s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.51
# Epoch 6: 27.81s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 7: 31.64s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 8: 37.26s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 9: 41.53s, train acc=0.90, train loss=0.39, validation acc=0.88, validation loss=0.42
# Epoch 10: 45.42s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 11: 50.37s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 12: 55.40s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 13: 59.26s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.38
# Epoch 14: 63.43s, train acc=0.91, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 15: 69.21s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.37
# Epoch 16: 73.12s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.37
# Epoch 17: 77.04s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 18: 83.37s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 19: 87.28s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 20: 91.12s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
#
# Test acc=0.90, Test loss=0.35
# Optimizer:sgd, Activation:elu, LearningRate:0.01
# Epoch 1: 6.08s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.47
# Epoch 2: 9.88s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.38
# Epoch 3: 13.65s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 4: 19.90s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.34
# Epoch 5: 23.64s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 6: 27.39s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.31
# Epoch 7: 33.63s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.30
# Epoch 8: 37.46s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 9: 41.20s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 10: 46.73s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.27
# Epoch 11: 50.97s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 12: 54.70s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 13: 59.07s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 14: 64.51s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 15: 68.30s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.24
# Epoch 16: 72.23s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.23
# Epoch 17: 78.41s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 18: 82.17s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 19: 85.95s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 20: 92.33s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.21
#
# Test acc=0.94, Test loss=0.21
# Optimizer:sgd, Activation:elu, LearningRate:0.001
# Epoch 1: 3.82s, train acc=0.69, train loss=1.59, validation acc=0.68, validation loss=1.60
# Epoch 2: 7.69s, train acc=0.77, train loss=1.14, validation acc=0.76, validation loss=1.16
# Epoch 3: 14.17s, train acc=0.81, train loss=0.88, validation acc=0.80, validation loss=0.90
# Epoch 4: 17.98s, train acc=0.83, train loss=0.73, validation acc=0.82, validation loss=0.76
# Epoch 5: 21.86s, train acc=0.85, train loss=0.64, validation acc=0.83, validation loss=0.67
# Epoch 6: 28.30s, train acc=0.86, train loss=0.57, validation acc=0.85, validation loss=0.60
# Epoch 7: 32.15s, train acc=0.86, train loss=0.53, validation acc=0.85, validation loss=0.56
# Epoch 8: 36.00s, train acc=0.87, train loss=0.49, validation acc=0.86, validation loss=0.52
# Epoch 9: 42.29s, train acc=0.88, train loss=0.46, validation acc=0.86, validation loss=0.50
# Epoch 10: 46.10s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.48
# Epoch 11: 49.96s, train acc=0.88, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 12: 55.20s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 13: 59.70s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 14: 63.55s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.42
# Epoch 15: 67.91s, train acc=0.89, train loss=0.38, validation acc=0.88, validation loss=0.41
# Epoch 16: 73.41s, train acc=0.90, train loss=0.37, validation acc=0.88, validation loss=0.41
# Epoch 17: 77.51s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 84.64s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 89.77s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 93.58s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
#
# Test acc=0.89, Test loss=0.38
# Optimizer:momentum, Activation:relu, LearningRate:0.01
# Epoch 1: 3.89s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 2: 9.83s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 3: 13.44s, train acc=0.91, train loss=0.30, validation acc=0.90, validation loss=0.34
# Epoch 4: 16.92s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 5: 22.84s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.30
# Epoch 6: 28.95s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 7: 32.35s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.26
# Epoch 8: 37.98s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.25
# Epoch 9: 41.38s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 10: 44.75s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 11: 50.65s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 12: 54.04s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 13: 57.47s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 14: 61.14s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 15: 66.85s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.19
# Epoch 16: 70.40s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 17: 73.99s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 18: 80.05s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 83.56s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 20: 87.10s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.16
# Optimizer:momentum, Activation:relu, LearningRate:0.001
# Epoch 1: 4.40s, train acc=0.46, train loss=2.09, validation acc=0.45, validation loss=2.09
# Epoch 2: 9.08s, train acc=0.62, train loss=1.74, validation acc=0.61, validation loss=1.75
# Epoch 3: 12.54s, train acc=0.72, train loss=1.34, validation acc=0.71, validation loss=1.35
# Epoch 4: 15.97s, train acc=0.79, train loss=1.03, validation acc=0.78, validation loss=1.04
# Epoch 5: 21.66s, train acc=0.82, train loss=0.83, validation acc=0.81, validation loss=0.85
# Epoch 6: 25.03s, train acc=0.84, train loss=0.70, validation acc=0.83, validation loss=0.73
# Epoch 7: 28.43s, train acc=0.85, train loss=0.62, validation acc=0.84, validation loss=0.65
# Epoch 8: 33.66s, train acc=0.86, train loss=0.56, validation acc=0.85, validation loss=0.59
# Epoch 9: 37.75s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.54
# Epoch 10: 41.21s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.51
# Epoch 11: 44.68s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 12: 50.76s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.46
# Epoch 13: 54.19s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 14: 57.67s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 15: 62.65s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.42
# Epoch 16: 66.87s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 17: 70.41s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 18: 73.86s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.39
# Epoch 19: 79.79s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 83.21s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
#
# Test acc=0.89, Test loss=0.38
# Optimizer:momentum, Activation:sigmoid, LearningRate:0.01
# Epoch 1: 4.06s, train acc=0.24, train loss=2.25, validation acc=0.24, validation loss=2.25
# Epoch 2: 10.67s, train acc=0.41, train loss=2.17, validation acc=0.41, validation loss=2.17
# Epoch 3: 14.83s, train acc=0.58, train loss=2.00, validation acc=0.57, validation loss=2.00
# Epoch 4: 19.04s, train acc=0.61, train loss=1.67, validation acc=0.61, validation loss=1.68
# Epoch 5: 25.72s, train acc=0.68, train loss=1.32, validation acc=0.67, validation loss=1.33
# Epoch 6: 29.78s, train acc=0.73, train loss=1.07, validation acc=0.72, validation loss=1.09
# Epoch 7: 33.84s, train acc=0.77, train loss=0.91, validation acc=0.76, validation loss=0.93
# Epoch 8: 40.50s, train acc=0.79, train loss=0.80, validation acc=0.79, validation loss=0.82
# Epoch 9: 44.70s, train acc=0.82, train loss=0.72, validation acc=0.81, validation loss=0.74
# Epoch 10: 49.01s, train acc=0.83, train loss=0.65, validation acc=0.83, validation loss=0.67
# Epoch 11: 55.19s, train acc=0.85, train loss=0.60, validation acc=0.84, validation loss=0.62
# Epoch 12: 59.30s, train acc=0.85, train loss=0.56, validation acc=0.85, validation loss=0.58
# Epoch 13: 63.75s, train acc=0.86, train loss=0.52, validation acc=0.86, validation loss=0.55
# Epoch 14: 69.82s, train acc=0.87, train loss=0.50, validation acc=0.86, validation loss=0.52
# Epoch 15: 74.00s, train acc=0.87, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 16: 79.06s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 17: 84.74s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.46
# Epoch 18: 89.00s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 19: 94.49s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 20: 99.43s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
#
# Test acc=0.88, Test loss=0.43
# Optimizer:momentum, Activation:sigmoid, LearningRate:0.001
# Epoch 1: 4.28s, train acc=0.12, train loss=2.30, validation acc=0.12, validation loss=2.30
# Epoch 2: 10.40s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 14.95s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 4: 19.07s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 5: 25.46s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 6: 29.56s, train acc=0.12, train loss=2.27, validation acc=0.12, validation loss=2.27
# Epoch 7: 33.79s, train acc=0.14, train loss=2.27, validation acc=0.13, validation loss=2.27
# Epoch 8: 40.43s, train acc=0.16, train loss=2.26, validation acc=0.16, validation loss=2.27
# Epoch 9: 44.63s, train acc=0.17, train loss=2.26, validation acc=0.17, validation loss=2.26
# Epoch 10: 48.86s, train acc=0.19, train loss=2.25, validation acc=0.19, validation loss=2.25
# Epoch 11: 55.44s, train acc=0.25, train loss=2.25, validation acc=0.25, validation loss=2.25
# Epoch 12: 59.50s, train acc=0.27, train loss=2.24, validation acc=0.27, validation loss=2.24
# Epoch 13: 63.64s, train acc=0.30, train loss=2.24, validation acc=0.30, validation loss=2.24
# Epoch 14: 70.30s, train acc=0.32, train loss=2.23, validation acc=0.32, validation loss=2.23
# Epoch 15: 74.39s, train acc=0.36, train loss=2.22, validation acc=0.35, validation loss=2.22
# Epoch 16: 78.46s, train acc=0.37, train loss=2.21, validation acc=0.37, validation loss=2.21
# Epoch 17: 84.84s, train acc=0.41, train loss=2.20, validation acc=0.40, validation loss=2.21
# Epoch 18: 88.98s, train acc=0.43, train loss=2.19, validation acc=0.42, validation loss=2.20
# Epoch 19: 93.22s, train acc=0.45, train loss=2.18, validation acc=0.44, validation loss=2.19
# Epoch 20: 99.70s, train acc=0.47, train loss=2.17, validation acc=0.46, validation loss=2.17
#
# Test acc=0.46, Test loss=2.17
# Optimizer:momentum, Activation:tanh, LearningRate:0.01
# Epoch 1: 6.48s, train acc=0.88, train loss=0.51, validation acc=0.86, validation loss=0.54
# Epoch 2: 16.14s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 3: 22.21s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 4: 30.72s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.34
# Epoch 5: 36.84s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 6: 45.36s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.30
# Epoch 7: 51.57s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 8: 60.14s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 9: 66.30s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 10: 74.69s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 11: 81.04s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 12: 89.10s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 13: 95.23s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.23
# Epoch 14: 103.43s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 15: 109.45s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 16: 117.76s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 17: 123.95s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 18: 131.71s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 19: 137.96s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 20: 146.10s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
#
# Test acc=0.95, Test loss=0.19
# Optimizer:momentum, Activation:tanh, LearningRate:0.001
# Epoch 1: 6.54s, train acc=0.69, train loss=1.67, validation acc=0.68, validation loss=1.67
# Epoch 2: 14.28s, train acc=0.76, train loss=1.24, validation acc=0.75, validation loss=1.26
# Epoch 3: 20.78s, train acc=0.81, train loss=0.99, validation acc=0.79, validation loss=1.01
# Epoch 4: 28.76s, train acc=0.83, train loss=0.84, validation acc=0.82, validation loss=0.86
# Epoch 5: 35.57s, train acc=0.84, train loss=0.74, validation acc=0.84, validation loss=0.76
# Epoch 6: 43.15s, train acc=0.85, train loss=0.66, validation acc=0.85, validation loss=0.69
# Epoch 7: 49.80s, train acc=0.86, train loss=0.61, validation acc=0.85, validation loss=0.64
# Epoch 8: 57.23s, train acc=0.87, train loss=0.57, validation acc=0.86, validation loss=0.60
# Epoch 9: 63.98s, train acc=0.87, train loss=0.54, validation acc=0.86, validation loss=0.57
# Epoch 10: 71.34s, train acc=0.88, train loss=0.51, validation acc=0.87, validation loss=0.54
# Epoch 11: 77.77s, train acc=0.88, train loss=0.49, validation acc=0.87, validation loss=0.52
# Epoch 12: 85.25s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 13: 91.85s, train acc=0.89, train loss=0.45, validation acc=0.88, validation loss=0.48
# Epoch 14: 99.03s, train acc=0.89, train loss=0.44, validation acc=0.88, validation loss=0.47
# Epoch 15: 105.64s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 16: 112.96s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 17: 119.65s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 18: 127.28s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 19: 133.64s, train acc=0.90, train loss=0.39, validation acc=0.89, validation loss=0.42
# Epoch 20: 141.01s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
#
# Test acc=0.89, Test loss=0.41
# Optimizer:momentum, Activation:leaky_relu, LearningRate:0.01
# Epoch 1: 3.67s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.49
# Epoch 2: 9.89s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 3: 13.51s, train acc=0.91, train loss=0.30, validation acc=0.90, validation loss=0.34
# Epoch 4: 17.12s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 5: 21.82s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.30
# Epoch 6: 26.75s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 7: 30.29s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 8: 33.93s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.25
# Epoch 9: 40.25s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.24
# Epoch 10: 43.88s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 11: 47.54s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 12: 53.64s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 13: 57.16s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.20
# Epoch 14: 60.78s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.19
# Epoch 15: 65.37s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 16: 70.26s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 17: 76.40s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 18: 82.48s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 86.07s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 20: 89.69s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.16
# Optimizer:momentum, Activation:leaky_relu, LearningRate:0.001
# Epoch 1: 4.53s, train acc=0.41, train loss=2.16, validation acc=0.42, validation loss=2.16
# Epoch 2: 9.44s, train acc=0.60, train loss=1.85, validation acc=0.59, validation loss=1.86
# Epoch 3: 12.98s, train acc=0.73, train loss=1.44, validation acc=0.72, validation loss=1.45
# Epoch 4: 16.54s, train acc=0.78, train loss=1.08, validation acc=0.77, validation loss=1.09
# Epoch 5: 22.83s, train acc=0.81, train loss=0.85, validation acc=0.80, validation loss=0.87
# Epoch 6: 26.52s, train acc=0.83, train loss=0.71, validation acc=0.82, validation loss=0.74
# Epoch 7: 30.17s, train acc=0.85, train loss=0.62, validation acc=0.84, validation loss=0.65
# Epoch 8: 36.36s, train acc=0.86, train loss=0.56, validation acc=0.85, validation loss=0.59
# Epoch 9: 39.99s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.55
# Epoch 10: 43.64s, train acc=0.87, train loss=0.48, validation acc=0.86, validation loss=0.51
# Epoch 11: 48.43s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.49
# Epoch 12: 53.00s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.47
# Epoch 13: 56.63s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 14: 60.21s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 15: 66.40s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.42
# Epoch 16: 70.19s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 17: 73.76s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 79.84s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.39
# Epoch 19: 83.51s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.38
# Epoch 20: 87.06s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
#
# Test acc=0.89, Test loss=0.38
# Optimizer:momentum, Activation:selu, LearningRate:0.01
# Epoch 1: 6.45s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 2: 11.03s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 3: 15.54s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.33
# Epoch 4: 22.58s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.31
# Epoch 5: 26.97s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.30
# Epoch 6: 31.41s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 7: 38.04s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 8: 42.47s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 9: 47.90s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 10: 53.35s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 11: 57.77s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.25
# Epoch 12: 64.23s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.24
# Epoch 13: 68.63s, train acc=0.95, train loss=0.17, validation acc=0.93, validation loss=0.23
# Epoch 14: 73.08s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 15: 79.98s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.22
# Epoch 16: 84.36s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.21
# Epoch 17: 88.69s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.21
# Epoch 18: 95.62s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.20
# Epoch 19: 99.94s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.20
# Epoch 20: 104.93s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.19
#
# Test acc=0.95, Test loss=0.19
# Optimizer:momentum, Activation:selu, LearningRate:0.001
# Epoch 1: 5.66s, train acc=0.78, train loss=1.06, validation acc=0.77, validation loss=1.08
# Epoch 2: 10.00s, train acc=0.83, train loss=0.74, validation acc=0.82, validation loss=0.76
# Epoch 3: 15.90s, train acc=0.86, train loss=0.60, validation acc=0.85, validation loss=0.63
# Epoch 4: 20.68s, train acc=0.87, train loss=0.53, validation acc=0.86, validation loss=0.56
# Epoch 5: 25.05s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.51
# Epoch 6: 31.97s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 7: 36.35s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 8: 40.67s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 9: 47.54s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.42
# Epoch 10: 51.93s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 11: 56.80s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 12: 62.93s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.39
# Epoch 13: 67.34s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 14: 72.98s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 15: 78.08s, train acc=0.91, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 16: 82.52s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.37
# Epoch 17: 89.44s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.37
# Epoch 18: 93.85s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 19: 98.28s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 20: 105.15s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
#
# Test acc=0.90, Test loss=0.35
# Optimizer:momentum, Activation:elu, LearningRate:0.01
# Epoch 1: 4.33s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.48
# Epoch 2: 8.87s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 3: 15.53s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 4: 19.70s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.34
# Epoch 5: 24.56s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.33
# Epoch 6: 30.41s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 7: 34.75s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.31
# Epoch 8: 40.02s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.29
# Epoch 9: 47.75s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 10: 51.96s, train acc=0.94, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 11: 58.48s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 12: 62.63s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 13: 66.79s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 14: 73.90s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 15: 78.10s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.23
# Epoch 16: 82.43s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.22
# Epoch 17: 89.23s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 18: 93.51s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 19: 97.71s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.20
# Epoch 20: 104.41s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
#
# Test acc=0.94, Test loss=0.20
# Optimizer:momentum, Activation:elu, LearningRate:0.001
# Epoch 1: 4.21s, train acc=0.68, train loss=1.68, validation acc=0.67, validation loss=1.69
# Epoch 2: 9.05s, train acc=0.78, train loss=1.19, validation acc=0.77, validation loss=1.20
# Epoch 3: 14.93s, train acc=0.82, train loss=0.89, validation acc=0.81, validation loss=0.91
# Epoch 4: 19.17s, train acc=0.84, train loss=0.73, validation acc=0.83, validation loss=0.75
# Epoch 5: 24.77s, train acc=0.86, train loss=0.63, validation acc=0.85, validation loss=0.65
# Epoch 6: 29.99s, train acc=0.86, train loss=0.56, validation acc=0.86, validation loss=0.58
# Epoch 7: 34.18s, train acc=0.87, train loss=0.51, validation acc=0.86, validation loss=0.54
# Epoch 8: 40.04s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.51
# Epoch 9: 44.74s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.48
# Epoch 10: 48.97s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.47
# Epoch 11: 55.32s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 12: 59.82s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 13: 63.99s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 14: 70.77s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 15: 74.97s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 16: 79.18s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 17: 85.95s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 90.26s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 94.61s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 101.30s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
#
# Test acc=0.89, Test loss=0.38
# Optimizer:adam, Activation:relu, LearningRate:0.01
# Epoch 1: 14.39s, train acc=0.89, train loss=0.37, validation acc=0.88, validation loss=0.41
# Epoch 2: 58.21s, train acc=0.91, train loss=0.32, validation acc=0.89, validation loss=0.38
# Epoch 3: 109.44s, train acc=0.90, train loss=0.32, validation acc=0.89, validation loss=0.39
# Epoch 4: 159.20s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.35
# Epoch 5: 212.47s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.35
# Epoch 6: 263.30s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.36
# Epoch 7: 313.75s, train acc=0.89, train loss=0.33, validation acc=0.87, validation loss=0.41
# Epoch 8: 365.35s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.35
# Epoch 9: 415.63s, train acc=0.93, train loss=0.27, validation acc=0.91, validation loss=0.35
# Epoch 10: 466.55s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.33
# Epoch 11: 518.62s, train acc=0.92, train loss=0.31, validation acc=0.90, validation loss=0.39
# Epoch 12: 573.82s, train acc=0.92, train loss=0.30, validation acc=0.90, validation loss=0.38
# Epoch 13: 625.82s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.36
# Epoch 14: 676.72s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.34
# Epoch 15: 728.69s, train acc=0.93, train loss=0.27, validation acc=0.91, validation loss=0.35
# ...
# Epoch 6: 125.40s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.44
# Epoch 7: 150.18s, train acc=0.90, train loss=0.34, validation acc=0.90, validation loss=0.39
# Epoch 8: 174.78s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.45
# Epoch 9: 198.98s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.38
# Epoch 10: 224.91s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.34
# Epoch 11: 253.61s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.37
# Epoch 12: 280.34s, train acc=0.93, train loss=0.27, validation acc=0.92, validation loss=0.32
# Epoch 13: 307.28s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.36
# Epoch 14: 334.93s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.37
# Epoch 15: 362.44s, train acc=0.92, train loss=0.30, validation acc=0.90, validation loss=0.35
# Epoch 16: 390.01s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.32
# Epoch 17: 417.32s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.33
# Epoch 18: 445.23s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.33
# Epoch 19: 472.50s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.30
# Epoch 20: 500.01s, train acc=0.93, train loss=0.27, validation acc=0.92, validation loss=0.32
#
# Test acc=0.92, Test loss=0.32
# Optimizer:adam, Activation:tanh, LearningRate:0.001
# Epoch 1: 16.43s, train acc=0.96, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 2: 34.05s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.13
# Epoch 3: 52.52s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.13
# Epoch 4: 70.94s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.12
# Epoch 5: 88.29s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 6: 107.79s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 7: 126.66s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 8: 144.45s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 9: 162.31s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.16
# Epoch 10: 179.90s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.12
# Epoch 11: 198.65s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.13
# Epoch 12: 215.65s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 13: 232.93s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.13
# Epoch 14: 250.45s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.13
# Epoch 15: 268.43s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.13
# Epoch 16: 285.45s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.13
# Epoch 17: 302.46s, train acc=1.00, train loss=0.00, validation acc=0.97, validation loss=0.13
# Epoch 18: 324.70s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 19: 347.62s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.15
# Epoch 20: 372.81s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.16
#
# Test acc=0.97, Test loss=0.16
# Optimizer:adam, Activation:leaky_relu, LearningRate:0.01
# Epoch 1: 18.98s, train acc=0.90, train loss=0.32, validation acc=0.89, validation loss=0.38
# Epoch 2: 38.58s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 3: 58.48s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.28
# Epoch 4: 79.85s, train acc=0.94, train loss=0.24, validation acc=0.92, validation loss=0.33
# Epoch 5: 103.37s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.30
# Epoch 6: 122.90s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.27
# Epoch 7: 140.33s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.29
# Epoch 8: 154.85s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.22
# Epoch 9: 170.04s, train acc=0.96, train loss=0.18, validation acc=0.94, validation loss=0.34
# Epoch 10: 185.05s, train acc=0.98, train loss=0.09, validation acc=0.96, validation loss=0.24
# Epoch 11: 199.85s, train acc=0.96, train loss=0.18, validation acc=0.94, validation loss=0.33
# Epoch 12: 214.04s, train acc=0.95, train loss=0.24, validation acc=0.93, validation loss=0.45
# Epoch 13: 229.02s, train acc=0.97, train loss=0.16, validation acc=0.95, validation loss=0.35
# Epoch 14: 243.22s, train acc=0.98, train loss=0.13, validation acc=0.95, validation loss=0.35
# Epoch 15: 258.30s, train acc=0.97, train loss=0.14, validation acc=0.95, validation loss=0.36
# Epoch 16: 272.40s, train acc=0.97, train loss=0.18, validation acc=0.95, validation loss=0.40
# Epoch 17: 288.01s, train acc=0.97, train loss=0.19, validation acc=0.95, validation loss=0.42
# Epoch 18: 302.68s, train acc=0.97, train loss=0.14, validation acc=0.95, validation loss=0.39
# Epoch 19: 318.04s, train acc=0.98, train loss=0.13, validation acc=0.95, validation loss=0.42
# Epoch 20: 333.53s, train acc=0.97, train loss=0.18, validation acc=0.95, validation loss=0.49
#
# Test acc=0.95, Test loss=0.49
# Optimizer:adam, Activation:leaky_relu, LearningRate:0.001
# Epoch 1: 14.66s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.13
# Epoch 2: 29.63s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 3: 44.32s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 4: 58.71s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 5: 73.44s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 6: 88.31s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 7: 103.26s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 8: 118.40s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Epoch 9: 133.27s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 10: 148.06s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 11: 162.85s, train acc=0.99, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 12: 177.92s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 13: 192.66s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 14: 207.36s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 15: 222.37s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.14
# Epoch 16: 236.69s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.15
# Epoch 17: 252.25s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.16
# Epoch 18: 270.16s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.15
# Epoch 19: 285.21s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Epoch 20: 299.95s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.16
#
# Test acc=0.98, Test loss=0.16
# Optimizer:adam, Activation:selu, LearningRate:0.01
# Epoch 1: 14.90s, train acc=0.92, train loss=0.35, validation acc=0.91, validation loss=0.42
# Epoch 2: 30.37s, train acc=0.86, train loss=0.54, validation acc=0.84, validation loss=0.64
# Epoch 3: 45.62s, train acc=0.90, train loss=0.48, validation acc=0.89, validation loss=0.59
# Epoch 4: 61.09s, train acc=0.95, train loss=0.30, validation acc=0.94, validation loss=0.43
# Epoch 5: 76.41s, train acc=0.95, train loss=0.29, validation acc=0.93, validation loss=0.44
# Epoch 6: 92.17s, train acc=0.96, train loss=0.25, validation acc=0.94, validation loss=0.42
# Epoch 7: 107.08s, train acc=0.94, train loss=0.33, validation acc=0.92, validation loss=0.46
# Epoch 8: 122.48s, train acc=0.95, train loss=0.30, validation acc=0.93, validation loss=0.49
# Epoch 9: 138.30s, train acc=0.96, train loss=0.32, validation acc=0.94, validation loss=0.53
# Epoch 10: 154.75s, train acc=0.96, train loss=0.27, validation acc=0.94, validation loss=0.47
# Epoch 11: 171.43s, train acc=0.97, train loss=0.18, validation acc=0.95, validation loss=0.35
# Epoch 12: 186.56s, train acc=0.95, train loss=0.37, validation acc=0.93, validation loss=0.58
# Epoch 13: 201.83s, train acc=0.97, train loss=0.18, validation acc=0.96, validation loss=0.38
# <ipython-input-6-1116b139aabc>:140: RuntimeWarning: overflow encountered in exp
#   return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
# <ipython-input-6-1116b139aabc>:138: RuntimeWarning: overflow encountered in exp
#   return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
# Epoch 14: 217.98s, train acc=0.97, train loss=0.20, validation acc=0.95, validation loss=0.42
# Epoch 15: 233.85s, train acc=0.97, train loss=0.22, validation acc=0.95, validation loss=0.43
# Epoch 16: 249.70s, train acc=0.97, train loss=0.25, validation acc=0.95, validation loss=0.45
# Epoch 17: 265.63s, train acc=0.96, train loss=0.29, validation acc=0.94, validation loss=0.51
# Epoch 18: 282.94s, train acc=0.96, train loss=0.29, validation acc=0.94, validation loss=0.52
# Epoch 19: 299.86s, train acc=0.97, train loss=0.31, validation acc=0.95, validation loss=0.57
# <ipython-input-6-1116b139aabc>:140: RuntimeWarning: overflow encountered in multiply
#   return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
# <ipython-input-6-1116b139aabc>:138: RuntimeWarning: overflow encountered in multiply
#   return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
# Epoch 20: 318.12s, train acc=0.97, train loss=0.20, validation acc=0.95, validation loss=0.46
#
# Test acc=0.95, Test loss=0.46
# Optimizer:adam, Activation:selu, LearningRate:0.001
# Epoch 1: 15.18s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 2: 30.25s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.13
# Epoch 3: 45.62s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 4: 61.35s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.13
# Epoch 5: 76.77s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 6: 92.29s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 7: 107.89s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.12
# Epoch 8: 123.63s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 9: 139.06s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 10: 154.36s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 11: 169.84s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.13
# Epoch 12: 185.55s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.15
# Epoch 13: 200.94s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 14: 216.24s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 15: 231.64s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 16: 246.67s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.18
# Epoch 17: 261.92s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.15
# Epoch 18: 277.57s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.19
# Epoch 19: 293.99s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.18
# Epoch 20: 309.72s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.18
#
# Test acc=0.97, Test loss=0.18
# Optimizer:adam, Activation:elu, LearningRate:0.01
# Epoch 1: 15.12s, train acc=0.93, train loss=0.28, validation acc=0.92, validation loss=0.35
# Epoch 2: 30.22s, train acc=0.93, train loss=0.30, validation acc=0.92, validation loss=0.37
# Epoch 3: 48.12s, train acc=0.95, train loss=0.26, validation acc=0.93, validation loss=0.39
# Epoch 4: 63.57s, train acc=0.97, train loss=0.15, validation acc=0.95, validation loss=0.23
# Epoch 5: 78.51s, train acc=0.96, train loss=0.19, validation acc=0.94, validation loss=0.30
# Epoch 6: 93.82s, train acc=0.96, train loss=0.17, validation acc=0.95, validation loss=0.27
# Epoch 7: 108.78s, train acc=0.97, train loss=0.13, validation acc=0.96, validation loss=0.24
# Epoch 8: 125.08s, train acc=0.96, train loss=0.21, validation acc=0.94, validation loss=0.37
# Epoch 9: 140.32s, train acc=0.96, train loss=0.19, validation acc=0.94, validation loss=0.32
# Epoch 10: 155.53s, train acc=0.97, train loss=0.15, validation acc=0.95, validation loss=0.31
# Epoch 11: 170.97s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.25
# Epoch 12: 186.51s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.28
# Epoch 13: 201.94s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.30
# <ipython-input-6-1116b139aabc>:124: RuntimeWarning: overflow encountered in exp
#   return np.where(x > 0, x, alpha * (np.exp(x) - 1))
# <ipython-input-6-1116b139aabc>:122: RuntimeWarning: overflow encountered in exp
#   return np.where(x > 0, 1, alpha * np.exp(x))
# Epoch 14: 217.19s, train acc=0.96, train loss=0.19, validation acc=0.94, validation loss=0.38
# Epoch 15: 233.26s, train acc=0.97, train loss=0.14, validation acc=0.95, validation loss=0.34
# Epoch 16: 249.25s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.33
# Epoch 17: 264.86s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.32
# Epoch 18: 280.65s, train acc=0.96, train loss=0.18, validation acc=0.93, validation loss=0.38
# Epoch 19: 298.25s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.32
# Epoch 20: 314.46s, train acc=0.96, train loss=0.19, validation acc=0.94, validation loss=0.38
#
# Test acc=0.94, Test loss=0.38
# Optimizer:adam, Activation:elu, LearningRate:0.001
# Epoch 1: 14.76s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 2: 29.53s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.12
# Epoch 3: 44.68s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 4: 59.97s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 5: 76.89s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 6: 91.92s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.14
# Epoch 7: 106.88s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 8: 121.80s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 9: 136.47s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.15
# Epoch 10: 151.76s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.13
# Epoch 11: 167.26s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 12: 182.70s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 13: 198.03s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.15
# Epoch 14: 213.21s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.15
# Epoch 15: 228.62s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Epoch 16: 243.81s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Epoch 17: 259.28s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.19
# Epoch 18: 274.82s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.16
# Epoch 19: 290.26s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Epoch 20: 305.04s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.17
#
# Test acc=0.98, Test loss=0.17

# %% [markdown]
# ---
#
# **Best Result:**
#
# Activation: leaky_relu
#
# Optimizer: Adam
#
# Learning Rate: 0.001
#
# Accuracy: 98%

# %%
best_result = max(results, key=lambda x: x["Accuracy"])
print("\nBest Result:")
print(f"Activation: {best_result['Activation']}")
print(f"Optimizer: {best_result['Optimizer']}")
print(f"Learning Rate: {best_result['Learning Rate']}")
print(f"Accuracy: {best_result['Accuracy']}")
# Out:
# Best Result:
# Activation: leaky_relu
# Optimizer: adam
# Learning Rate: 0.001
# Accuracy: 98

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units (midpoints of intervals between input points)
    biases = (input_data[1:] + input_data[:-1]) / 2

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros((num_relus, x_points.shape[0]))

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        current_slope = (target_labels[j + 1] - target_labels[j]) / (input_data[j + 1] - input_data[j])
        relu_weights[j] = current_slope - previous_slope
        previous_slope = current_slope

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)


predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)

x_points = x_points.detach().cpu().numpy()
activation_map = activation_map.detach().cpu().numpy()
predicted_output = predicted_output.detach().cpu().numpy()

plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ##############################---TODO---##############################
    activation_dict = {
        'relu': nn.ReLU(),
        'sigmoid': nn.Sigmoid(),
        'tanh': nn.Tanh(),
        'leaky_relu': nn.LeakyReLU(),
        'selu': nn.SELU(),
        'elu': nn.ELU()
    }

    for i, units in enumerate(hidden_unit_nums):
        layer = nn.Linear(in_num, units)
        self.mlp.add_module(f'Hidden_Linear_{i + 1}', layer)
        if activation_fn in activation_dict:
            self.mlp.add_module(f'Activation_{i + 1}', activation_dict[activation_fn])
        else:
            raise ValueError(f"Unsupported activation function: {activation_fn}")

        in_num = units

    out_layer = nn.Linear(in_num, output_feature_num)
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    num_features = (poly_degree + 1) * (poly_degree + 2) // 2 - 1
    N, D = X.shape
    poly_X = torch.zeros((N, num_features), device=X.device)
    feature_idx = 0
    for i in range(poly_degree + 1):
        for j in range(i + 1):
            if i + j > 0:
                poly_X[:, feature_idx] = (X[:, 0] ** (i - j)) * (X[:, 1] ** j)
                feature_idx += 1
    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 70.03
# Accuracy on the 800 testing samples: 68.12
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch('relu', input_feature_num=2, hidden_unit_nums=[128], output_feature_num=K)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.81
# Accuracy on the 800 testing samples: 97.62
